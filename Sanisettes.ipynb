# %%
import pandas as pd

df = pd.read_csv("sanisettesparis.csv", delimiter=";")

# %%
df["HORAIRE"].replace({"6 h - 1 h": "6h/1h", "24 h / 24": "24h/24h", "6 h - 22 h":"6h/22h", "24h/24":"24h/24h","19 h - 7 h":"19h/7h", "10h à 22h":"10h/22h"}, inplace=True)

# %%
df.RELAIS_BEBE.fillna("Non", inplace=True)

# %%
is_NaN = df.ARRONDISSEMENT.isnull()
list(df.ARRONDISSEMENT[is_NaN].index)
# Out:
# [19,
#  20,
#  21,
#  22,
#  23,
#  24,
#  50,
#  51,
#  52,
#  70,
#  76,
#  77,
#  78,
#  79,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  156,
#  157,
#  158,
#  159,
#  184,
#  185,
#  186,
#  187,
#  188,
#  217,
#  218,
#  219,
#  220,
#  221,
#  248,
#  249,
#  277,
#  278,
#  279,
#  280,
#  281,
#  282,
#  283,
#  297,
#  298,
#  299,
#  300,
#  301,
#  302,
#  303,
#  328,
#  329,
#  330,
#  357,
#  358,
#  388,
#  389,
#  390,
#  391,
#  392,
#  393,
#  422,
#  423,
#  424,
#  425,
#  426,
#  427,
#  428,
#  429,
#  430,
#  431,
#  451,
#  452,
#  453,
#  454,
#  455,
#  480,
#  481,
#  482,
#  483,
#  484,
#  485,
#  486,
#  487,
#  519,
#  520,
#  521,
#  539,
#  540,
#  541,
#  542,
#  543,
#  578,
#  579,
#  580,
#  581,
#  600,
#  601,
#  602,
#  603,
#  604]

# %%
for i in list(df.ARRONDISSEMENT[is_NaN].index):
    print(df.loc[[i]])
# Out:
#          TYPE  STATUT                ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 19  SANISETTE     NaN  2  RUE DE LA LINGERIE             NaN  24h/24h
#
#    ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 19       Oui         Non                  NaN
#
#                                             geo_shape  \
# 19  {"coordinates": [[2.346478360952597, 48.860283...
#
#                            geo_point_2d
# 19  48.86028377588714,2.346478360952597
#          TYPE  STATUT                  ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 20  SANISETTE     NaN  79  BOULEVARD DU TEMPLE             NaN  24h/24h
#
#    ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 20       Oui         Non                  NaN
#
#                                             geo_shape  \
# 20  {"coordinates": [[2.366305527110086, 48.863554...
#
#                            geo_point_2d
# 20  48.86355463067629,2.366305527110086
#          TYPE  STATUT             ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 21  SANISETTE     NaN  6  QUAI DE GESVRES             NaN  24h/24h       Oui
#
#    RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 21         Non                  NaN
#
#                                             geo_shape  \
# 21  {"coordinates": [[2.349796463968451, 48.856486...
#
#                             geo_point_2d
# 21  48.856486160078234,2.349796463968451
#          TYPE  STATUT                ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 22  SANISETTE     NaN  123  RUE SAINT MARTIN             NaN  24h/24h
#
#    ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 22       Oui         Non                  NaN
#
#                                             geo_shape  \
# 22  {"coordinates": [[2.351315750121665, 48.860790...
#
#                            geo_point_2d
# 22  48.86079042790049,2.351315750121665
#          TYPE  STATUT      ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 23  SANISETTE     NaN  RUE ORTOLON             NaN  6h/22h       Oui
#
#    RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 23         Non                  NaN
#
#                                             geo_shape  \
# 23  {"coordinates": [[2.350590246372097, 48.843194...
#
#                           geo_point_2d
# 23  48.8431945688025,2.350590246372097
#          TYPE  STATUT            ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 24  SANISETTE     NaN  40  RUE DE SEVRES             NaN  6h/22h       Oui
#
#    RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 24         Non                  NaN
#
#                                             geo_shape  \
# 24  {"coordinates": [[2.323054655081175, 48.849834...
#
#                            geo_point_2d
# 24  48.84983487675197,2.323054655081175
#          TYPE  STATUT          ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 50  SANISETTE     NaN  RUE COQUILLIERE             NaN   6h/1h       Oui
#
#    RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 50         Non                  NaN
#
#                                             geo_shape  \
# 50  {"coordinates": [[2.342472298693266, 48.863547...
#
#                           geo_point_2d
# 50  48.8635474009773,2.342472298693266
#          TYPE  STATUT                      ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 51  SANISETTE     NaN  23  BOULEVARD DE SEBASTOPOL             NaN  24h/24h
#
#    ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 51       Oui         Non                  NaN
#
#                                             geo_shape  \
# 51  {"coordinates": [[2.348837230656095, 48.859855...
#
#                            geo_point_2d
# 51  48.85985523410491,2.348837230656095
#          TYPE  STATUT                  ADRESSE  ARRONDISSEMENT HORAIRE  \
# 52  SANISETTE     NaN  BOULEVARD DE SEBASTOPOL             NaN  6h/22h
#
#    ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 52       Oui         Non                  NaN
#
#                                             geo_shape  \
# 52  {"coordinates": [[2.35161126358933, 48.8648280...
#
#                          geo_point_2d
# 52  48.8648280162637,2.35161126358933
#          TYPE  STATUT             ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 70  SANISETTE     NaN  PLACE DES ABBESSES             NaN  19h/7h       Oui
#
#    RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 70         Non                  NaN
#
#                                             geo_shape  \
# 70  {"coordinates": [[2.338685892541593, 48.884530...
#
#                             geo_point_2d
# 70  48.884530709513804,2.338685892541593
#          TYPE  STATUT                        ADRESSE  ARRONDISSEMENT HORAIRE  \
# 76  SANISETTE     NaN  face au 13 PLACE DE LA BOURSE             NaN  6h/22h
#
#    ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 76       Oui         Non                  NaN
#
#                                             geo_shape  \
# 76  {"coordinates": [[2.34062639508409, 48.8689183...
#
#                           geo_point_2d
# 76  48.86891836470313,2.34062639508409
#          TYPE  STATUT              ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 77  SANISETTE     NaN  117  RUE MONTMARTRE             NaN  6h/22h       Oui
#
#    RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 77         Non                  NaN
#
#                                             geo_shape  \
# 77  {"coordinates": [[2.343235945649155, 48.868749...
#
#                            geo_point_2d
# 77  48.86874906648296,2.343235945649155
#          TYPE  STATUT                   ADRESSE  ARRONDISSEMENT HORAIRE  \
# 78  SANISETTE     NaN  AVENUE DE L OBSERVATOIRE             NaN  6h/22h
#
#    ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 78       Oui         Non                  NaN
#
#                                             geo_shape  \
# 78  {"coordinates": [[2.337228424428142, 48.842224...
#
#                            geo_point_2d
# 78  48.84222410041659,2.337228424428142
#          TYPE  STATUT       ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 79  SANISETTE     NaN  PLACE VAUBAN             NaN  6h/22h       Oui
#
#    RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 79         Non                  NaN
#
#                                             geo_shape  \
# 79  {"coordinates": [[2.311319652738035, 48.853625...
#
#                             geo_point_2d
# 79  48.853625040539285,2.311319652738035
#           TYPE  STATUT                                            ADRESSE  \
# 113  SANISETTE     NaN  Jardin DES HALLES ALLEE BLAISE CENDRARS SUD OUEST
#
#      ARRONDISSEMENT HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 113             NaN  6h/22h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 113  {"coordinates": [[2.344254327997302, 48.862221...
#
#                              geo_point_2d
# 113  48.862221666357485,2.344254327997302
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT HORAIRE  \
# 114  SANISETTE     NaN  85  BOULEVARD DE SEBASTOPOL             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 114       Oui         Non                  NaN
#
#                                              geo_shape  \
# 114  {"coordinates": [[2.35161126358933, 48.8648280...
#
#                           geo_point_2d
# 114  48.8648280162637,2.35161126358933
#           TYPE  STATUT            ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 115  SANISETTE     NaN  91  RUE D ABOUKIR             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 115         Non                  NaN
#
#                                              geo_shape  \
# 115  {"coordinates": [[2.348450028836779, 48.868162...
#
#                             geo_point_2d
# 115  48.86816218874815,2.348450028836779
#           TYPE  STATUT                              ADRESSE  ARRONDISSEMENT  \
# 116  SANISETTE     NaN  1  BOULEVARD DES FILLES DU CALVAIRE             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 116  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 116  {"coordinates": [[2.367032423762319, 48.861123...
#
#                              geo_point_2d
# 116  48.861123131655724,2.367032423762319
#           TYPE  STATUT                    ADRESSE  ARRONDISSEMENT HORAIRE  \
# 117  SANISETTE     NaN  face au 171 RUE DU TEMPLE             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 117       Oui         Non                  NaN
#
#                                              geo_shape  \
# 117  {"coordinates": [[2.36013286100841, 48.8649756...
#
#                            geo_point_2d
# 117  48.86497566729412,2.36013286100841
#           TYPE  STATUT               ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 118  SANISETTE     NaN  10 bis RUE DE MOUSSY             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 118       Oui         Non                  NaN
#
#                                              geo_shape  \
# 118  {"coordinates": [[2.35581305149286, 48.8578325...
#
#                            geo_point_2d
# 118  48.85783250805626,2.35581305149286
#           TYPE  STATUT                         ADRESSE  ARRONDISSEMENT  \
# 119  SANISETTE     NaN  88 ter BOULEVARD DE PORT ROYAL             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 119  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 119  {"coordinates": [[2.338731588164609, 48.839200...
#
#                             geo_point_2d
# 119  48.83920071261067,2.338731588164609
#           TYPE  STATUT                 ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 120  SANISETTE     NaN  BOULEVARD SAINT MICHEL             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 120       Oui         Non                  NaN
#
#                                              geo_shape  \
# 120  {"coordinates": [[2.337484628388991, 48.841754...
#
#                             geo_point_2d
# 120  48.84175443253953,2.337484628388991
#           TYPE  STATUT      ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 121  SANISETTE     NaN  QUAI BRANLY             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 121         Non                  NaN
#
#                                              geo_shape  \
# 121  {"coordinates": [[2.292315949121437, 48.858066...
#
#                             geo_point_2d
# 121  48.85806633367225,2.292315949121437
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT HORAIRE  \
# 122  SANISETTE     NaN  AVENUE FRANKLIN D ROOSEVELT             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 122       Oui         Non                  NaN
#
#                                              geo_shape  \
# 122  {"coordinates": [[2.310160918160172, 48.870141...
#
#                             geo_point_2d
# 122  48.87014131314519,2.310160918160172
#           TYPE  STATUT                ADRESSE  ARRONDISSEMENT HORAIRE  \
# 123  SANISETTE     NaN  79 bis RUE LA FAYETTE             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 123       Oui         Non                  NaN
#
#                                              geo_shape  \
# 123  {"coordinates": [[2.346852652338503, 48.876742...
#
#                             geo_point_2d
# 123  48.87674207808279,2.346852652338503
#           TYPE  STATUT             ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 156  SANISETTE     NaN  9  RUE COQUILLIERE             NaN   6h/1h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 156         Non                  NaN
#
#                                              geo_shape  \
# 156  {"coordinates": [[2.342472298693266, 48.863547...
#
#                            geo_point_2d
# 156  48.8635474009773,2.342472298693266
#           TYPE  STATUT                         ADRESSE  ARRONDISSEMENT  \
# 157  SANISETTE     NaN  face au 2 RUE AUBRY LE BOUCHER             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 157  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 157  {"coordinates": [[2.350397746470584, 48.860212...
#
#                             geo_point_2d
# 157  48.86021286930935,2.350397746470584
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 158  SANISETTE     NaN  130 ter BOULEVARD DE CLICHY             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 158       Oui         Non                  NaN
#
#                                              geo_shape  \
# 158  {"coordinates": [[2.328969615964768, 48.884214...
#
#                              geo_point_2d
# 158  48.884214349237055,2.328969615964768
#           TYPE  STATUT              ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 159  SANISETTE     NaN  11  AVENUE TRUDAINE             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 159         Non                  NaN
#
#                                              geo_shape  \
# 159  {"coordinates": [[2.345516263472959, 48.881665...
#
#                             geo_point_2d
# 159  48.88166539264047,2.345516263472959
#           TYPE  STATUT              ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 184  SANISETTE     NaN  17  AVENUE VICTORIA             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 184       Oui         Non                  NaN
#
#                                              geo_shape  \
# 184  {"coordinates": [[2.346535672660024, 48.857970...
#
#                              geo_point_2d
# 184  48.857970439927115,2.346535672660024
#           TYPE  STATUT                       ADRESSE  ARRONDISSEMENT HORAIRE  \
# 185  SANISETTE     NaN  109  BOULEVARD DE SEBASTOPOL             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 185       Oui         Non                  NaN
#
#                                              geo_shape  \
# 185  {"coordinates": [[2.352726650613073, 48.866819...
#
#                             geo_point_2d
# 185  48.86681987649092,2.352726650613073
#           TYPE  STATUT       ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 186  SANISETTE     NaN  RUE D ARCOLE             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 186         Non                  NaN
#
#                                              geo_shape  \
# 186  {"coordinates": [[2.3492432036278, 48.85381205...
#
#                            geo_point_2d
# 186  48.853812057284806,2.3492432036278
#           TYPE  STATUT                   ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 187  SANISETTE     NaN  face au 75 bis RUE MONGE             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 187       Oui         Non                  NaN
#
#                                              geo_shape  \
# 187  {"coordinates": [[2.35207298397874, 48.8431229...
#
#                            geo_point_2d
# 187  48.84312297015192,2.35207298397874
#           TYPE  STATUT                               ADRESSE  ARRONDISSEMENT  \
# 188  SANISETTE     NaN  CHAMPS DE MARS avenue GENERAL FERRIE             NaN
#
#     HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 188  6h/22h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 188  {"coordinates": [[2.296943316091291, 48.857182...
#
#                             geo_point_2d
# 188  48.85718239169635,2.296943316091291
#           TYPE  STATUT                            ADRESSE  ARRONDISSEMENT  \
# 217  SANISETTE     NaN  face au 73 BOULEVARD SAINT MICHEL             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 217  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 217  {"coordinates": [[2.340044296677426, 48.846129...
#
#                             geo_point_2d
# 217  48.84612923935423,2.340044296677426
#           TYPE  STATUT          ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 218  SANISETTE     NaN  17  RUE DU FOUR             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 218         Non                  NaN
#
#                                              geo_shape  \
# 218  {"coordinates": [[2.334590272454289, 48.852721...
#
#                             geo_point_2d
# 218  48.85272198682075,2.334590272454289
#           TYPE  STATUT         ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 219  SANISETTE     NaN  COURS LA REINE             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 219         Non                  NaN
#
#                                              geo_shape  \
# 219  {"coordinates": [[2.318088034663091, 48.865148...
#
#                             geo_point_2d
# 219  48.86514883797138,2.318088034663091
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 220  SANISETTE     NaN  opposé au 44 AVENUE GABRIEL             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 220       Oui         Non                  NaN
#
#                                              geo_shape  \
# 220  {"coordinates": [[2.31276020722228, 48.8694709...
#
#                             geo_point_2d
# 220  48.869470956238764,2.31276020722228
#           TYPE  STATUT                         ADRESSE  ARRONDISSEMENT  \
# 221  SANISETTE     NaN  face au 19 AVENUE DE FRIEDLAND             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 221  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 221  {"coordinates": [[2.302361992982482, 48.874613...
#
#                              geo_point_2d
# 221  48.874613485017605,2.302361992982482
#           TYPE  STATUT          ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 248  SANISETTE     NaN  8  RUE D ARCOLE             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 248         Non                  NaN
#
#                                              geo_shape  \
# 248  {"coordinates": [[2.349398891032556, 48.854019...
#
#                            geo_point_2d
# 248  48.8540198901374,2.349398891032556
#           TYPE  STATUT                        ADRESSE  ARRONDISSEMENT  \
# 249  SANISETTE     NaN  51  BOULEVARD DE ROCHECHOUART             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 249  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 249  {"coordinates": [[2.341432909012633, 48.882316...
#
#                              geo_point_2d
# 249  48.882316150207735,2.341432909012633
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT HORAIRE  \
# 277  SANISETTE     NaN  55  BOULEVARD DE SEBASTOPOL             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 277       Oui         Non                  NaN
#
#                                              geo_shape  \
# 277  {"coordinates": [[2.350203080907802, 48.862313...
#
#                              geo_point_2d
# 277  48.862313183032356,2.350203080907802
#           TYPE  STATUT                  ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 278  SANISETTE     NaN  39  PLACE DES DEUX ECUS             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 278       Oui         Non                  NaN
#
#                                              geo_shape  \
# 278  {"coordinates": [[2.341836175822233, 48.863156...
#
#                              geo_point_2d
# 278  48.863156681649215,2.341836175822233
#           TYPE  STATUT                    ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 279  SANISETTE     NaN  15  BOULEVARD SAINT DENIS             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 279       Oui         Non                  NaN
#
#                                              geo_shape  \
# 279  {"coordinates": [[2.353502085687314, 48.869408...
#
#                              geo_point_2d
# 279  48.869408298985206,2.353502085687314
#           TYPE  STATUT                ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 280  SANISETTE     NaN  115  RUE SAINT MARTIN             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 280       Oui         Non                  NaN
#
#                                              geo_shape  \
# 280  {"coordinates": [[2.351171125654263, 48.860523...
#
#                             geo_point_2d
# 280  48.86052384157859,2.351171125654263
#           TYPE  STATUT                     ADRESSE  ARRONDISSEMENT HORAIRE  \
# 281  SANISETTE     NaN  78  BOULEVARD SAINT MARCEL             NaN   6h/1h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 281       Oui         Non                  NaN
#
#                                              geo_shape  \
# 281  {"coordinates": [[2.353543641100616, 48.837418...
#
#                             geo_point_2d
# 281  48.83741847058166,2.353543641100616
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT HORAIRE  \
# 282  SANISETTE     NaN  51  BOULEVARD DE COURCELLES             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 282       Oui         Non                  NaN
#
#                                              geo_shape  \
# 282  {"coordinates": [[2.304028164576791, 48.879227...
#
#                              geo_point_2d
# 282  48.879227198587344,2.304028164576791
#           TYPE  STATUT                             ADRESSE  ARRONDISSEMENT  \
# 283  SANISETTE     NaN  opposé au 168 BOULEVARD DE MAGENTA             NaN
#
#     HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 283  6h/22h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 283  {"coordinates": [[2.349610003378711, 48.883270...
#
#                              geo_point_2d
# 283  48.883270091603826,2.349610003378711
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT HORAIRE  \
# 297  SANISETTE     NaN  37  BOULEVARD DES CAPUCINES             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 297       Oui         Non                  NaN
#
#                                              geo_shape  \
# 297  {"coordinates": [[2.329345376568483, 48.870058...
#
#                              geo_point_2d
# 297  48.870058233825205,2.329345376568483
#           TYPE  STATUT                 ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 298  SANISETTE     NaN  123  RUE SAINT ANTOINE             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 298       Oui         Non                  NaN
#
#                                              geo_shape  \
# 298  {"coordinates": [[2.360419701884549, 48.855303...
#
#                             geo_point_2d
# 298  48.85530319788792,2.360419701884549
#           TYPE  STATUT             ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 299  SANISETTE     NaN  RUE DE L AVE MARIA             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 299         Non                  NaN
#
#                                              geo_shape  \
# 299  {"coordinates": [[2.359582804553574, 48.853210...
#
#                             geo_point_2d
# 299  48.85321055139778,2.359582804553574
#           TYPE  STATUT        ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 300  SANISETTE     NaN  2  RUE MORNAY             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 300         Non                  NaN
#
#                                              geo_shape  \
# 300  {"coordinates": [[2.366123193813519, 48.849474...
#
#                              geo_point_2d
# 300  48.849474962211744,2.366123193813519
#           TYPE  STATUT                     ADRESSE  ARRONDISSEMENT HORAIRE  \
# 301  SANISETTE     NaN  9  BOULEVARD SAINT GERMAIN             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 301       Oui         Non                  NaN
#
#                                              geo_shape  \
# 301  {"coordinates": [[2.354846182358385, 48.849330...
#
#                              geo_point_2d
# 301  48.849330262603885,2.354846182358385
#           TYPE  STATUT          ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 302  SANISETTE     NaN  2  PLACE JOFFRE             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 302         Non                  NaN
#
#                                              geo_shape  \
# 302  {"coordinates": [[2.305083210870264, 48.854301...
#
#                              geo_point_2d
# 302  48.854301176148155,2.305083210870264
#           TYPE  STATUT                        ADRESSE  ARRONDISSEMENT  \
# 303  SANISETTE     NaN  45  BOULEVARD DE ROCHECHOUART             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 303  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 303  {"coordinates": [[2.343497799728155, 48.882709...
#
#                              geo_point_2d
# 303  48.882709085896316,2.343497799728155
#           TYPE  STATUT               ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 328  SANISETTE     NaN  14  RUE SAINT MARTIN             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 328       Oui         Non                  NaN
#
#                                              geo_shape  \
# 328  {"coordinates": [[2.349797594005607, 48.858200...
#
#                              geo_point_2d
# 328  48.858200967363395,2.349797594005607
#           TYPE  STATUT                   ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 329  SANISETTE     NaN  face au 50 RUE DE RIVOLI             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 329       Oui         Non                  NaN
#
#                                              geo_shape  \
# 329  {"coordinates": [[2.354183092290366, 48.856789...
#
#                             geo_point_2d
# 329  48.85678942451888,2.354183092290366
#           TYPE  STATUT             ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 330  SANISETTE     NaN  8  RUE JEAN CALVIN             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 330         Non                  NaN
#
#                                              geo_shape  \
# 330  {"coordinates": [[2.348691572286761, 48.841640...
#
#                            geo_point_2d
# 330  48.8416407780507,2.348691572286761
#           TYPE  STATUT              ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 357  SANISETTE     NaN  32  AVENUE GEORGE V             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 357         Non                  NaN
#
#                                              geo_shape  \
# 357  {"coordinates": [[2.30122008119351, 48.8688403...
#
#                             geo_point_2d
# 357  48.868840348754716,2.30122008119351
#           TYPE  STATUT                  ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 358  SANISETTE     NaN  65  BOULEVARD DE CLICHY             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 358       Oui         Non                  NaN
#
#                                              geo_shape  \
# 358  {"coordinates": [[2.331784835499315, 48.883981...
#
#                             geo_point_2d
# 358  48.88398130352188,2.331784835499315
#           TYPE  STATUT         ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 388  SANISETTE     NaN  44  RUE BERGER             NaN   6h/1h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 388         Non                  NaN
#
#                                              geo_shape  \
# 388  {"coordinates": [[2.342203221829112, 48.862340...
#
#                             geo_point_2d
# 388  48.86234030275965,2.342203221829112
#           TYPE  STATUT                                 ADRESSE  \
# 389  SANISETTE     NaN  face au 34 RUE DU GRENIER SAINT LAZARE
#
#      ARRONDISSEMENT HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 389             NaN  6h/22h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 389  {"coordinates": [[2.352717714733575, 48.863093...
#
#                            geo_point_2d
# 389  48.8630936107319,2.352717714733575
#           TYPE  STATUT                 ADRESSE  ARRONDISSEMENT HORAIRE  \
# 390  SANISETTE     NaN  123  RUE SAINT JACQUES             NaN   6h/1h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 390       Oui         Non                  NaN
#
#                                              geo_shape  \
# 390  {"coordinates": [[2.343987824033075, 48.847812...
#
#                             geo_point_2d
# 390  48.84781204558067,2.343987824033075
#           TYPE  STATUT                             ADRESSE  ARRONDISSEMENT  \
# 391  SANISETTE     NaN  face au 139 BOULEVARD SAINT MICHEL             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 391  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 391  {"coordinates": [[2.337484628388991, 48.841754...
#
#                             geo_point_2d
# 391  48.84175443253953,2.337484628388991
#           TYPE  STATUT                       ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 392  SANISETTE     NaN  186  BOULEVARD SAINT GERMAIN             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 392       Oui         Non                  NaN
#
#                                              geo_shape  \
# 392  {"coordinates": [[2.330995211131629, 48.854428...
#
#                           geo_point_2d
# 392  48.854428127216,2.330995211131629
#           TYPE  STATUT                ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 393  SANISETTE     NaN  41  PLACE DE FINLANDE             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 393       Oui         Non                  NaN
#
#                                              geo_shape  \
# 393  {"coordinates": [[2.310808622720738, 48.862476...
#
#                             geo_point_2d
# 393  48.86247699359682,2.310808622720738
#           TYPE  STATUT                ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 422  SANISETTE     NaN  41  BOULEVARD BOURDON             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 422       Oui         Non                  NaN
#
#                                              geo_shape  \
# 422  {"coordinates": [[2.368356693963534, 48.852642...
#
#                            geo_point_2d
# 422  48.8526426890932,2.368356693963534
#           TYPE  STATUT            ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 423  SANISETTE     NaN  RUE SAINT JACQUES             NaN   6h/1h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 423         Non                  NaN
#
#                                              geo_shape  \
# 423  {"coordinates": [[2.343987824033075, 48.847812...
#
#                             geo_point_2d
# 423  48.84781204558067,2.343987824033075
#           TYPE  STATUT         ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 424  SANISETTE     NaN  26  RUE BUFFON             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 424         Non                  NaN
#
#                                              geo_shape  \
# 424  {"coordinates": [[2.356224683117664, 48.841308...
#
#                              geo_point_2d
# 424  48.841308049754275,2.356224683117664
#           TYPE  STATUT                 ADRESSE  ARRONDISSEMENT HORAIRE  \
# 425  SANISETTE     NaN  9  AVENUE DES GOBELINS             NaN   6h/1h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 425       Oui         Non                  NaN
#
#                                              geo_shape  \
# 425  {"coordinates": [[2.351186507903939, 48.837952...
#
#                             geo_point_2d
# 425  48.83795209152188,2.351186507903939
#           TYPE  STATUT                            ADRESSE  ARRONDISSEMENT  \
# 426  SANISETTE     NaN  135 bis BOULEVARD DU MONTPARNASSE             NaN
#
#     HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 426  6h/22h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 426  {"coordinates": [[2.332328604387268, 48.841202...
#
#                              geo_point_2d
# 426  48.841202569450836,2.332328604387268
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 427  SANISETTE     NaN  75  BOULEVARD SAINT GERMAIN             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 427       Oui         Non                  NaN
#
#                                              geo_shape  \
# 427  {"coordinates": [[2.342803068261682, 48.851388...
#
#                              geo_point_2d
# 427  48.851388278836424,2.342803068261682
#           TYPE  STATUT                   ADRESSE  ARRONDISSEMENT HORAIRE  \
# 428  SANISETTE     NaN  JARDIN DU CHAMPS DE MARS             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 428       Oui         Non                  NaN
#
#                                              geo_shape  \
# 428  {"coordinates": [[2.300536612101094, 48.854891...
#
#                            geo_point_2d
# 428  48.8548917342077,2.300536612101094
#           TYPE  STATUT                       ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 429  SANISETTE     NaN  12  PLACE GEORGES GUILLAUMIN             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 429       Oui         Non                  NaN
#
#                                              geo_shape  \
# 429  {"coordinates": [[2.303210664567426, 48.874774...
#
#                             geo_point_2d
# 429  48.87477424791767,2.303210664567426
#           TYPE  STATUT     ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 430  SANISETTE     NaN  RUE VIGNON             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 430         Non                  NaN
#
#                                              geo_shape  \
# 430  {"coordinates": [[2.326530446470896, 48.872527...
#
#                             geo_point_2d
# 430  48.87252784014988,2.326530446470896
#           TYPE  STATUT                 ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 431  SANISETTE     NaN  5  BOULEVARD DE CLICHY             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 431       Oui         Non                  NaN
#
#                                              geo_shape  \
# 431  {"coordinates": [[2.339163301036448, 48.882089...
#
#                              geo_point_2d
# 431  48.882089018714574,2.339163301036448
#           TYPE  STATUT                   ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 451  SANISETTE     NaN  QUAI DE L HOTEL DE VILLE             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 451       Oui         Non                  NaN
#
#                                              geo_shape  \
# 451  {"coordinates": [[2.356023599656361, 48.854150...
#
#                              geo_point_2d
# 451  48.854150671810245,2.356023599656361
#           TYPE  STATUT                     ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 452  SANISETTE     NaN  face au 12 RUE DE BABYLONE             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 452       Oui         Non                  NaN
#
#                                              geo_shape  \
# 452  {"coordinates": [[2.325180137951544, 48.851626...
#
#                              geo_point_2d
# 452  48.851626831079074,2.325180137951544
#           TYPE  STATUT                    ADRESSE  ARRONDISSEMENT HORAIRE  \
# 453  SANISETTE     NaN  44  BOULEVARD MALESHERBES             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 453       Oui         Non                  NaN
#
#                                              geo_shape  \
# 453  {"coordinates": [[2.320451685354317, 48.874358...
#
#                             geo_point_2d
# 453  48.87435840225736,2.320451685354317
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 454  SANISETTE     NaN  face au 4 AVENUE DE MESSINE             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 454       Oui         Non                  NaN
#
#                                              geo_shape  \
# 454  {"coordinates": [[2.315115171552737, 48.875417...
#
#                             geo_point_2d
# 454  48.87541798841174,2.315115171552737
#           TYPE  STATUT                    ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 455  SANISETTE     NaN  BOULEVARD DE ROCHECHOUART             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 455       Oui         Non                  NaN
#
#                                              geo_shape  \
# 455  {"coordinates": [[2.343497799728155, 48.882709...
#
#                              geo_point_2d
# 455  48.882709085896316,2.343497799728155
#           TYPE  STATUT          ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 480  SANISETTE     NaN  73  RUE REAUMUR             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 480         Non                  NaN
#
#                                              geo_shape  \
# 480  {"coordinates": [[2.349571365122188, 48.866793...
#
#                             geo_point_2d
# 480  48.86679354360574,2.349571365122188
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT HORAIRE  \
# 481  SANISETTE     NaN  90  BOULEVARD DE SEBASTOPOL             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 481       Oui         Non                  NaN
#
#                                              geo_shape  \
# 481  {"coordinates": [[2.352544366189737, 48.866017...
#
#                             geo_point_2d
# 481  48.86601791753035,2.352544366189737
#           TYPE  STATUT                 ADRESSE  ARRONDISSEMENT HORAIRE  \
# 482  SANISETTE     NaN  2  RUE DES QUATRE FILS             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 482       Oui         Non                  NaN
#
#                                              geo_shape  \
# 482  {"coordinates": [[2.360700687397763, 48.860059...
#
#                           geo_point_2d
# 482  48.860059866028,2.360700687397763
#           TYPE  STATUT                 ADRESSE  ARRONDISSEMENT HORAIRE  \
# 483  SANISETTE     NaN  4  RUE SALOMON DE CAUS             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 483       Oui         Non                  NaN
#
#                                              geo_shape  \
# 483  {"coordinates": [[2.354020375521618, 48.867364...
#
#                            geo_point_2d
# 483  48.8673644300438,2.354020375521618
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 484  SANISETTE     NaN  36  BOULEVARD DE SEBASTOPOL             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 484       Oui         Non                  NaN
#
#                                              geo_shape  \
# 484  {"coordinates": [[2.350030857031587, 48.861537...
#
#                              geo_point_2d
# 484  48.861537352383735,2.350030857031587
#           TYPE  STATUT                ADRESSE  ARRONDISSEMENT HORAIRE  \
# 485  SANISETTE     NaN  BOULEVARD MALESHERBES             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 485       Oui         Non                  NaN
#
#                                              geo_shape  \
# 485  {"coordinates": [[2.323053984722453, 48.870723...
#
#                             geo_point_2d
# 485  48.87072323445267,2.323053984722453
#           TYPE  STATUT            ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 486  SANISETTE     NaN  2  AVENUE MARCEAU             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 486         Non                  NaN
#
#                                              geo_shape  \
# 486  {"coordinates": [[2.300183446079439, 48.865193...
#
#                             geo_point_2d
# 486  48.86519333667549,2.300183446079439
#           TYPE  STATUT                        ADRESSE  ARRONDISSEMENT  \
# 487  SANISETTE     NaN  17  BOULEVARD DE ROCHECHOUART             NaN
#
#      HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 487  24h/24h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 487  {"coordinates": [[2.34743316865442, 48.8834206...
#
#                             geo_point_2d
# 487  48.883420611557554,2.34743316865442
#           TYPE  STATUT            ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 519  SANISETTE     NaN  37  RUE DU LOUVRE             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 519         Non                  NaN
#
#                                              geo_shape  \
# 519  {"coordinates": [[2.343820992881231, 48.867437...
#
#                            geo_point_2d
# 519  48.8674378410879,2.343820992881231
#           TYPE  STATUT          ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 520  SANISETTE     NaN  4  RUE POLIVEAU             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 520         Non                  NaN
#
#                                              geo_shape  \
# 520  {"coordinates": [[2.361273263570859, 48.840393...
#
#                            geo_point_2d
# 520  48.8403933177024,2.361273263570859
#           TYPE  STATUT              ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 521  SANISETTE     NaN  21  RUE D AMSTERDAM             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 521       Oui         Non                  NaN
#
#                                              geo_shape  \
# 521  {"coordinates": [[2.327036875810606, 48.877605...
#
#                              geo_point_2d
# 521  48.877605646896434,2.327036875810606
#           TYPE  STATUT             ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 539  SANISETTE     NaN  107  RUE RAMBUTEAU             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 539         Non                  NaN
#
#                                              geo_shape  \
# 539  {"coordinates": [[2.346392662102407, 48.862748...
#
#                             geo_point_2d
# 539  48.86274833004129,2.346392662102407
#           TYPE  STATUT                     ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 540  SANISETTE     NaN  27  BOULEVARD POISSONNIERE             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 540       Oui         Non                  NaN
#
#                                              geo_shape  \
# 540  {"coordinates": [[2.343654073079795, 48.871299...
#
#                             geo_point_2d
# 540  48.87129988583528,2.343654073079795
#           TYPE  STATUT          ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 541  SANISETTE     NaN  QUAI DE GESVRES             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 541         Non                  NaN
#
#                                              geo_shape  \
# 541  {"coordinates": [[2.349796463968451, 48.856486...
#
#                              geo_point_2d
# 541  48.856486160078234,2.349796463968451
#           TYPE  STATUT         ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 542  SANISETTE     NaN  4  RUE JUSSIEU             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 542         Non                  NaN
#
#                                              geo_shape  \
# 542  {"coordinates": [[2.354872194164979, 48.846225...
#
#                             geo_point_2d
# 542  48.84622521629629,2.354872194164979
#           TYPE  STATUT                         ADRESSE  ARRONDISSEMENT  \
# 543  SANISETTE     NaN  4  AVENUE FRANKLIN D ROOSEVELT             NaN
#
#     HORAIRE ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 543  6h/22h       Oui         Non                  NaN
#
#                                              geo_shape  \
# 543  {"coordinates": [[2.310160918160172, 48.870141...
#
#                             geo_point_2d
# 543  48.87014131314519,2.310160918160172
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT HORAIRE  \
# 578  SANISETTE     NaN  69  BOULEVARD DE SEBASTOPOL             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 578       Oui         Non                  NaN
#
#                                              geo_shape  \
# 578  {"coordinates": [[2.350962736416814, 48.863662...
#
#                             geo_point_2d
# 578  48.86366249322703,2.350962736416814
#           TYPE  STATUT              ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 579  SANISETTE     NaN  25  RUE PASTOURELLE             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 579         Non                  NaN
#
#                                              geo_shape  \
# 579  {"coordinates": [[2.359364861798902, 48.862744...
#
#                             geo_point_2d
# 579  48.86274437683079,2.359364861798902
#           TYPE  STATUT        ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 580  SANISETTE     NaN  RUE DE SEVRES             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 580         Non                  NaN
#
#                                              geo_shape  \
# 580  {"coordinates": [[2.323054655081175, 48.849834...
#
#                             geo_point_2d
# 580  48.84983487675197,2.323054655081175
#           TYPE  STATUT                 ADRESSE  ARRONDISSEMENT  HORAIRE  \
# 581  SANISETTE     NaN  AVENUE CHARLES FLOQUET             NaN  24h/24h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 581       Oui         Non                  NaN
#
#                                              geo_shape  \
# 581  {"coordinates": [[2.295895903904689, 48.855104...
#
#                              geo_point_2d
# 581  48.855104384442974,2.295895903904689
#           TYPE  STATUT                      ADRESSE  ARRONDISSEMENT HORAIRE  \
# 600  SANISETTE     NaN  82  BOULEVARD DE SEBASTOPOL             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 600       Oui         Non                  NaN
#
#                                              geo_shape  \
# 600  {"coordinates": [[2.352249091270851, 48.865503...
#
#                             geo_point_2d
# 600  48.86550351402495,2.352249091270851
#           TYPE  STATUT            ADRESSE  ARRONDISSEMENT  HORAIRE ACCES_PMR  \
# 601  SANISETTE     NaN  RUE SAINT ANTOINE             NaN  24h/24h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 601         Non                  NaN
#
#                                              geo_shape  \
# 601  {"coordinates": [[2.360419701884549, 48.855303...
#
#                             geo_point_2d
# 601  48.85530319788792,2.360419701884549
#           TYPE  STATUT                   ADRESSE  ARRONDISSEMENT HORAIRE  \
# 602  SANISETTE     NaN  21 bis BOULEVARD BOURDON             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 602       Oui         Non                  NaN
#
#                                              geo_shape  \
# 602  {"coordinates": [[2.366735495873733, 48.849930...
#
#                              geo_point_2d
# 602  48.849930706291325,2.366735495873733
#           TYPE  STATUT     ADRESSE  ARRONDISSEMENT HORAIRE ACCES_PMR  \
# 603  SANISETTE     NaN  RUE CUVIER             NaN  6h/22h       Oui
#
#     RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 603         Non                  NaN
#
#                                              geo_shape  \
# 603  {"coordinates": [[2.360394697155951, 48.844396...
#
#                             geo_point_2d
# 603  48.84439660262885,2.360394697155951
#           TYPE  STATUT                ADRESSE  ARRONDISSEMENT HORAIRE  \
# 604  SANISETTE     NaN  85  BOULEVARD RASPAIL             NaN  6h/22h
#
#     ACCES_PMR RELAIS_BEBE URL_FICHE_EQUIPEMENT  \
# 604       Oui         Non                  NaN
#
#                                              geo_shape  \
# 604  {"coordinates": [[2.327969092306715, 48.847683...
#
#                             geo_point_2d
# 604  48.84768309080963,2.327969092306715

# %%
df.ARRONDISSEMENT.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 610    False
# 611    False
# 612    False
# 613    False
# 614    False
# Name: ARRONDISSEMENT, Length: 615, dtype: bool

# %%
print(df)
# Out:
#                       TYPE  STATUT  \
# 0                SANISETTE     NaN
# 1                SANISETTE     NaN
# 2                SANISETTE     NaN
# 3                SANISETTE     NaN
# 4                SANISETTE     NaN
# ..                     ...     ...
# 610              TOILETTES     NaN
# 611              TOILETTES     NaN
# 612                URINOIR     NaN
# 613              TOILETTES     NaN
# 614  WC PUBLICS PERMANENTS     NaN
#
#                                                ADRESSE  ARRONDISSEMENT  \
# 0                                    RUE ROBERT BLACHE         75010.0
# 1                          face au 50 QUAI DE JEMMAPES         75010.0
# 2                   face au 4 BOULEVARD RICHARD LENOIR         75011.0
# 3               opposé au 13 BOULEVARD DE MENILMONTANT         75011.0
# 4                  face au 7 BOULEVARD DE MENILMONTANT         75011.0
# ..                                                 ...             ...
# 610               JARDIN JEAN-CLAUDE NICOLAS FORESTIER         75013.0
# 611                                 PARC ANDRE CITROEN         75015.0
# 612  JARDIN TINO ROSSI - MUSEE DE LA SCULPTURE EN P...         75005.0
# 613                           PARC DES BUTTES CHAUMONT         75019.0
# 614                                Parc Rives de Seine         75001.0
#
#                    HORAIRE ACCES_PMR RELAIS_BEBE  \
# 0                    6h/1h       Oui         Non
# 1                  24h/24h       Oui         Non
# 2                  24h/24h       Oui         Non
# 3                   6h/22h       Oui         Non
# 4                   6h/22h       Oui         Non
# ..                     ...       ...         ...
# 610  Voir fiche équipement       Non         Non
# 611  Voir fiche équipement       Non         Non
# 612  Voir fiche équipement       Non         Non
# 613  Voir fiche équipement       Non         Non
# 614                10h/22h       Oui         Non
#
#                                   URL_FICHE_EQUIPEMENT  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 610  https://www.paris.fr/equipements/jardin-jean-c...
# 611  https://www.paris.fr/equipements/parc-andre-ci...
# 612  https://www.paris.fr/equipements/jardin-tino-r...
# 613  https://www.paris.fr/equipements/parc-des-butt...
# 614                                                NaN
#
#                                              geo_shape  \
# 0    {"coordinates": [[2.363990501903871, 48.877014...
# 1    {"coordinates": [[2.36659750721216, 48.8700279...
# 2    {"coordinates": [[2.36970018383113, 48.8539831...
# 3    {"coordinates": [[2.389122267946412, 48.859234...
# 4    {"coordinates": [[2.38932122025704, 48.8588174...
# ..                                                 ...
# 610  {"coordinates": [[2.348072406221041, 48.818848...
# 611  {"coordinates": [[2.275296807339177, 48.842096...
# 612  {"coordinates": [[2.361597962737386, 48.846994...
# 613  {"coordinates": [[2.379927468657875, 48.878124...
# 614  {"coordinates": [[2.344286199307675, 48.857853...
#
#                              geo_point_2d
# 0     48.87701431314924,2.363990501903871
# 1      48.87002790121456,2.36659750721216
# 2     48.853983171388194,2.36970018383113
# 3     48.85923461154838,2.389122267946412
# 4      48.85881749412743,2.38932122025704
# ..                                    ...
# 610   48.81884809913537,2.348072406221041
# 611    48.8420964537002,2.275296807339177
# 612   48.84699411929912,2.361597962737386
# 613  48.878124294408764,2.379927468657875
# 614   48.85785376524151,2.344286199307675
#
# [615 rows x 10 columns]
